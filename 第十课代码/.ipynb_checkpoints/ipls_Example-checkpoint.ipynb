# %% [markdown]
# ## ipls原理

# %% [markdown]
# 区间偏最小二乘法将整个光谱区域划分为多个等宽的子区间， 假设为n个； 在每个子区间上进行偏最小二乘回归，建立待测品质的"局部回归模型"，也就是可以得到n个局部回归模型；以均方根无误差MSE值为各模型的精度衡量标准，取精度最高的局部模型所在的子区间为特征波段。

# %%
import numpy as np
import pandas as pd
import scipy.io as sio
from sklearn.model_selection import train_test_split
from draws import IPLS_bar
import IPLS

# %%
if __name__ == '__main__':

    mat = sio.loadmat(r'E:\Documents\DAY\cornmat.mat')
    X = ('m5','mp5','mp6')
    Y = ('oil', 'starch', 'pro', 'water')
    intervals = 20
    for a in X: #m5
        intervals_list = []
        mse_list = []
        for b in Y: #oil
            x = mat[a]
            y = mat[b]
            x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33)
            IPLS.ipls(intervals, x_train, x_test, y_train, y_test)
    IPLS_bar(title,intervals_list,mse_list)
# Out:
# 当前区间: 1
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 2
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 3
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 4
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 5
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 6
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 7
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 8
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 9
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 10
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 11
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 12
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 13
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 14
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 15
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 16
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 17
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 18
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 19
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# 当前区间: 20
# 迭代当前主成分数量: 5
# 迭代当前主成分数量: 6
# 迭代当前主成分数量: 7
# 迭代当前主成分数量: 8
# 迭代当前主成分数量: 9
# 迭代当前主成分数量: 10
# 迭代当前主成分数量: 11
# 迭代当前主成分数量: 12
# 迭代当前主成分数量: 13
# 迭代当前主成分数量: 14
# 迭代当前主成分数量: 15
# 迭代当前主成分数量: 16
# 迭代当前主成分数量: 17
# 迭代当前主成分数量: 18
# 迭代当前主成分数量: 19
# 迭代当前主成分数量: 20
# 迭代当前主成分数量: 21
# 迭代当前主成分数量: 22
# 迭代当前主成分数量: 23
# 迭代当前主成分数量: 24
# 迭代当前主成分数量: 25
# 迭代当前主成分数量: 26
# 迭代当前主成分数量: 27
# 迭代当前主成分数量: 28
# 迭代当前主成分数量: 29
# [0.021717429529065503, 0.018762422304696696, 0.02591973237288758, 0.023573801987427305, 0.019617187777105773, 0.04519705301851517, 0.034538982968376014, 0.03906835059646917, 0.011785142336835433, 0.015475136084361697, 0.03198314450626593, 0.027522209437830132, 0.039074914494204895, 0.03340002050127801, 0.025812622381193553, 0.023215554047653037, 0.008933374613098899, 0.007511326256923794, 0.03837179761036892, 0.02169361252818863]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3f0ae4e7b05b> in <module>
#      10 ipls(intervals, x_train, x_test, y_train, y_test)
#      11
# ---> 12 IPLS_bar(title,intervals_list,mse_list)
#
# NameError: name 'IPLS_bar' is not defined
